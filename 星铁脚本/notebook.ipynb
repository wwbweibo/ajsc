# %%
from main import device_image_capture_and_convert, preset_image_loader, check_game_status
import matplotlib.pyplot as plt
import cv2

# %%
# img = cv2.imread('images/chat-select.png', cv2.IMREAD_UNCHANGED)
# plt.imshow(img[][:][:], cmap='gray')

# %%
chat_continue, auto_battle, chat_select, chat_begin, chat_begintask, phone_select, phone_close = preset_image_loader()

# %%
plt.imshow(chat_select, cmap='gray')

# %%
plt.imshow(chat_continue, cmap='gray')

# %%
plt.imshow(chat_begin, cmap='gray')

# %%
plt.imshow(chat_begintask, cmap='gray')

# %%
edge = device_image_capture_and_convert()
plt.imshow(edge, cmap='gray')
# Out:
# /sdcard/screen.png: 1 file pulled, 0 skipped. 30.5 MB/s (2092193 bytes in 0.065s)

# %%
result = check_game_status(edge, chat_continue, chat_select, chat_begin, chat_begintask, phone_select, phone_close)
print(result)
# Out:
# ('phone_close', 2705, 113)

# %%
if result is not None:
    t, x, y  =result
    image = cv2.imread('screen.png')
    cv2.rectangle(image, (x + 80, y + 100), (x + 150, y + 150), (0, 255, 0), 3)
    plt.imshow(image)

# %%
import os

# %%
print(os.name)
# Out:
# nt
